# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirapatlnwza/Python_dataviz2023/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Exam

# %% [markdown]
# ## Link DashBoard
# https://lookerstudio.google.com/reporting/1635f258-3c79-44a2-b10a-331c03d5657d

# %% [markdown]
# ## สมาชิกในกลุ่ม
# 1. นายเศรษฐา สุวินชัย 633020361-5 หน้าที่ Dashboard
# 2. นางสาวพิมพิกา ยอดศรี 643020511-3 หน้าที่ Dashboard
# 3. นายภัทรธร ก้อนมณี 643020513-9 หน้าที่ Coding
# 4. นายรัชชานนท์ ทิพย์พิมานพร 643020515-5 หน้าที่ Coding
# 5. นางสาวรัตชฎากร นามวงศ์ 643020517-1 หน้าที่ Dashboard
# 6. นางสาวสิรภัทร ไชยมาตย์ 643020523-6 หน้าที่ Dashboard

# %% [markdown]
# ## Import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# เข้า path ที่เราสนใจใน google drive
import os
os.chdir('/content/drive/MyDrive/DataViz_FinalData')

# %%
# !ls # เช็คว่ามีไฟล์อะไรบ้างที่อยู่ใน path นั้น
# Out:
# 2017.csv       Operation.gsheet				POS_transactions_20190213-20190226.csv
# 201902.csv     POS_operator_logs_20171207-20171219.csv	POS_transactions_20190328-20190410.csv
# 201904.csv     POS_operator_logs_20190213-20190226.csv	tran.csv
# Data.csv       POS_operator_logs_20190328-20190410.csv	tran.gsheet
# Operation.csv  POS_transactions_20171207-20171219.csv	x.csv

# %%
import pandas as pd
import numpy as np

# %%
df_op1 = pd.read_csv('/content/drive/MyDrive/DataViz_FinalData/POS_operator_logs_20171207-20171219.csv')
df_op2 = pd.read_csv('/content/drive/MyDrive/DataViz_FinalData/POS_operator_logs_20190213-20190226.csv')
df_op3 = pd.read_csv('/content/drive/MyDrive/DataViz_FinalData/POS_operator_logs_20190328-20190410.csv')
df_tran1 = pd.read_csv('/content/drive/MyDrive/DataViz_FinalData/POS_transactions_20171207-20171219.csv')
df_tran2 = pd.read_csv('/content/drive/MyDrive/DataViz_FinalData/POS_transactions_20190213-20190226.csv')
df_tran3 = pd.read_csv('/content/drive/MyDrive/DataViz_FinalData/POS_transactions_20190328-20190410.csv')

# %%
df_op1
# Out:
#       WorkstationGroupID  WorkstationID           TranID        BeginDateTime  \
# 0                      8             16    1712071060162  2017-12-07T06:04:01
# 1                      8             15    1712071060152  2017-12-07T06:04:15
# 2                      8             14    1712071060142  2017-12-07T06:05:36
# 3                      8             18    1712071060182  2017-12-07T06:05:41
# 4                      8             17    1712071060172  2017-12-07T06:05:56
# ...                  ...            ...              ...                  ...
# 4703                   8             14  171219106014514  2017-12-19T22:00:22
# 4704                   1             21  171219106021873  2017-12-19T22:02:53
# 4705                   8             15  171219106015506  2017-12-19T22:05:05
# 4706                   1             21  171219106021890  2017-12-19T22:09:47
# 4707                   1             22  171219106022935  2017-12-19T22:12:44
#
# ...

# %%
df_op2
# Out:
#       WorkstationGroupID  WorkstationID           TranID        BeginDateTime  \
# 0                      8             19    1902131060192  2019-02-13T05:37:55
# 1                      8             18    1902131060182  2019-02-13T05:37:55
# 2                      8             17    1902131060172  2019-02-13T05:38:43
# 3                      1              4     190213106042  2019-02-13T07:01:26
# 4                      1              7     190213106072  2019-02-13T07:01:57
# ...                  ...            ...              ...                  ...
# 5213                   1             12  190226106012628  2019-02-26T21:44:52
# 5214                   1             20  190226106020667  2019-02-26T21:53:12
# 5215                   1             12  190226106012644  2019-02-26T22:00:49
# 5216                   1             12  190226106012645  2019-02-26T22:01:48
# 5217                   1             12  190226106012648  2019-02-26T22:03:46
#
# ...

# %%
df_op3
# Out:
#       WorkstationGroupID  WorkstationID           TranID        BeginDateTime  \
# 0                      8             19    1903281060192  2019-03-28T06:08:13
# 1                      8             18    1903281060182  2019-03-28T06:09:13
# 2                      8             17    1903281060172  2019-03-28T06:08:33
# 3                      1              4     190328106042  2019-03-28T07:04:45
# 4                      1              6     190328106062  2019-03-28T07:18:38
# ...                  ...            ...              ...                  ...
# 4173                   1              3   19041010603798  2019-04-10T21:53:58
# 4174                   1              4  190410106041042  2019-04-10T21:54:30
# 4175                   1              4  190410106041044  2019-04-10T21:55:05
# 4176                   1              5   19041010605515  2019-04-10T22:00:25
# 4177                   1              4  190410106041061  2019-04-10T22:10:57
#
# ...

# %%
op_concat = pd.concat([df_op1,df_op2,df_op3], ignore_index = True)
op_concat
# Out:
#        WorkstationGroupID  WorkstationID           TranID  \
# 0                       8             16    1712071060162
# 1                       8             15    1712071060152
# 2                       8             14    1712071060142
# 3                       8             18    1712071060182
# 4                       8             17    1712071060172
# ...                   ...            ...              ...
# 14099                   1              3   19041010603798
# 14100                   1              4  190410106041042
# 14101                   1              4  190410106041044
# 14102                   1              5   19041010605515
# 14103                   1              4  190410106041061
#
#              BeginDateTime  OperatorID            Items
# 0      2017-12-07T06:04:01         266   OperatorSignOn
# 1      2017-12-07T06:04:15         265   OperatorSignOn
# 2      2017-12-07T06:05:36         264   OperatorSignOn
# ...

# %%
op = op_concat[['OperatorID','BeginDateTime','Items']]

# %%
op
# Out:
#        OperatorID       BeginDateTime            Items
# 0             266 2017-12-07 06:04:01   OperatorSignOn
# 1             265 2017-12-07 06:04:15   OperatorSignOn
# 2             264 2017-12-07 06:05:36   OperatorSignOn
# 3             268 2017-12-07 06:05:41   OperatorSignOn
# 4             267 2017-12-07 06:05:56   OperatorSignOn
# ...           ...                 ...              ...
# 14099         104 2019-04-10 21:53:58  OperatorSignOff
# 14100         304 2019-04-10 21:54:30  OperatorSignOff
# 14101         104 2019-04-10 21:55:05   OperatorSignOn
# 14102         136 2019-04-10 22:00:25  OperatorSignOff
# 14103         104 2019-04-10 22:10:57  OperatorSignOff
#
# [14104 rows x 3 columns]

# %%
df_tran1
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 66858                   1    1712191060847  2017-12-19T11:48:35
# 66859                   1    1712191060848  2017-12-19T11:49:47
# 66860                   1    1712191060849  2017-12-19T11:50:39
# 66861                   1    1712191060851  2017-12-19T11:51:36
# 66862                   1    1712191060853  2017-12-19T11:52:37
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
df_tran2
# Out:
#        WorkstationGroupID          TranID        BeginDateTime  \
# 0                       1  19022310606223  2019-02-23T14:35:12
# 1                       1    190213106054  2019-02-13T07:50:14
# 2                       1    190213106055  2019-02-13T07:50:40
# 3                       1    190213106058  2019-02-13T07:54:30
# 4                       1    190213106059  2019-02-13T07:55:21
# ...                   ...             ...                  ...
# 47061                   1  19022310606490  2019-02-23T19:39:47
# 47062                   1  19022310606494  2019-02-23T19:40:59
# 47063                   1  19022310606496  2019-02-23T19:41:29
# 47064                   1  19022310606499  2019-02-23T19:42:32
# 47065                   1  19022310606500  2019-02-23T19:43:19
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2019-02-23T14:35:12          10         0          2       1   False
# ...

# %%
df_tran3
# Out:
#        WorkstationGroupID                 TranID        BeginDateTime  \
# 0                       1  19040310601356.000000  2019-04-03T13:28:17
# 1                       1  19032910607385.000000  2019-03-29T14:04:50
# 2                       1  19032910607386.000000  2019-03-29T14:05:52
# 3                       1  19032910607387.000000  2019-03-29T14:07:19
# 4                       1  19032910607389.000000  2019-03-29T14:08:08
# ...                   ...                    ...                  ...
# 49335                   1 190410100000000.000000  2019-04-10T14:05:20
# 49336                   1 190410100000000.000000  2019-04-10T14:06:39
# 49337                   1 190410100000000.000000  2019-04-10T14:07:51
# 49338                   1 190410100000000.000000  2019-04-10T14:09:46
# 49339                   1 190410100000000.000000  2019-04-10T14:10:29
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# ...

# %%
tran_concat = pd.concat([df_tran1,df_tran2,df_tran3], ignore_index = True)
tran_concat
# Out:
#         WorkstationGroupID        TranID        BeginDateTime  \
# 0                        1  1.712071e+14  2017-12-07T14:23:23
# 1                        1  1.712071e+14  2017-12-07T14:25:09
# 2                        1  1.712071e+14  2017-12-07T14:27:28
# 3                        1  1.712071e+14  2017-12-07T14:28:04
# 4                        1  1.712071e+14  2017-12-07T14:29:40
# ...                    ...           ...                  ...
# 163264                   1  1.904101e+14  2019-04-10T14:05:20
# 163265                   1  1.904101e+14  2019-04-10T14:06:39
# 163266                   1  1.904101e+14  2019-04-10T14:07:51
# 163267                   1  1.904101e+14  2019-04-10T14:09:46
# 163268                   1  1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
# กำหนดตัวเลือกแสดงผลตัวเลข
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
# ตัดทศนิยม ใน TranID
columns_to_format = ['TranID']

def remove_decimal(value):
    return int(value)

tran_concat[columns_to_format] = tran_concat[columns_to_format].apply(lambda x: x.apply(remove_decimal))

# %%
tran_concat
# Out:
#         WorkstationGroupID           TranID        BeginDateTime  \
# 0                        1  171207106022464  2017-12-07T14:23:23
# 1                        1  171207106022465  2017-12-07T14:25:09
# 2                        1  171207106022466  2017-12-07T14:27:28
# 3                        1  171207106022467  2017-12-07T14:28:04
# 4                        1  171207106022468  2017-12-07T14:29:40
# ...                    ...              ...                  ...
# 163264                   1  190410100000000  2019-04-10T14:05:20
# 163265                   1  190410100000000  2019-04-10T14:06:39
# 163266                   1  190410100000000  2019-04-10T14:07:51
# 163267                   1  190410100000000  2019-04-10T14:09:46
# 163268                   1  190410100000000  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %% [markdown]
# ## Checking Missing Values

# %%
op_concat.isnull().any() # ตาราง operator 'ข้อมูลการสั่งซื้อ' ไม่มีค่า Null
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
tran_concat.isnull().any() # ตาราง transection 'ข้อมูลการสั่งซื้อ' ไม่มีค่า Null
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tran = tran_concat[['TranID','BeginDateTime','EndDateTime','OperatorID','TranTime']]

# %%
x = op.merge(tran, on='OperatorID',how = 'inner')

# %%
x
# Out:
#           OperatorID      BeginDateTime_x            Items           TranID  \
# 0                266  2017-12-07T06:04:01   OperatorSignOn    1712071060164
# 1                266  2017-12-07T06:04:01   OperatorSignOn    1712071060167
# 2                266  2017-12-07T06:04:01   OperatorSignOn    1712071060169
# 3                266  2017-12-07T06:04:01   OperatorSignOn   17120710601611
# 4                266  2017-12-07T06:04:01   OperatorSignOn   17120710601613
# ...              ...                  ...              ...              ...
# 46476693         304  2019-04-10T21:54:30  OperatorSignOff  190410100000000
# 46476694         304  2019-04-10T21:54:30  OperatorSignOff  190410100000000
# 46476695         304  2019-04-10T21:54:30  OperatorSignOff  190410100000000
# 46476696         304  2019-04-10T21:54:30  OperatorSignOff  190410100000000
# 46476697         304  2019-04-10T21:54:30  OperatorSignOff  190410100000000
#
# ...

# %%
x.isnull().any()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-3f94dc2675af> in <cell line: 1>()
# ----> 1 x.isnull().any()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in isnull(self)
#    6385         DataFrame.isnull is an alias for DataFrame.isna.
#    6386         """
# -> 6387         return self.isna()
#    6388
#    6389     @doc(NDFrame.notna, klass=_shared_doc_kwargs["klass"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in isna(self)
#    6377     @doc(NDFrame.isna, klass=_shared_doc_kwargs["klass"])
#    6378     def isna(self) -> DataFrame:
# -> 6379         result = self._constructor(self._mgr.isna(func=isna))
#    6380         return result.__finalize__(self, method="isna")
#    6381
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in isna(self, func)
#     141     @final
# ...

# %%
print(x.shape)
x.dropna()

# %%
x.duplicated()

# %%
x.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','Data.csv'))

# %%
tran_concat.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','tran.csv'))

# %%
op_concat.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','Operation.csv'))

# %% [markdown]
# ## Test

# %%
bool_series = op_concat.duplicated(subset='TranID')
# passing NOT of bool series to see unique values only
x4 = op_concat[~bool_series]
# displaying data
x5 = x4.reset_index()

# %%
bool_series = tran_concat.duplicated(subset='TranID')
# passing NOT of bool series to see unique values only
x6 = tran_concat[~bool_series]
# displaying data
x7 = x6.reset_index()

# %%
op1 = x5[['WorkstationGroupID','WorkstationID','TranID','OperatorID','Items']]

# %%
op1
# Out:
#        WorkstationGroupID  WorkstationID           TranID  OperatorID  \
# 0                       8             16    1712071060162         266
# 1                       8             15    1712071060152         265
# 2                       8             14    1712071060142         264
# 3                       8             18    1712071060182         268
# 4                       8             17    1712071060172         267
# ...                   ...            ...              ...         ...
# 14069                   1              3   19041010603798         104
# 14070                   1              4  190410106041042         304
# 14071                   1              4  190410106041044         104
# 14072                   1              5   19041010605515         136
# 14073                   1              4  190410106041061         104
#
#                  Items
# 0       OperatorSignOn
# 1       OperatorSignOn
# 2       OperatorSignOn
# 3       OperatorSignOn
# ...

# %%
tran1 = x7[['WorkstationGroupID','TranID','OperatorID','ArtNum','TNcash','TNcard','Amount']]

# %%
tran1 = tran1.applymap(int)

# %%
tran1
# Out:
#         WorkstationGroupID           TranID  OperatorID  ArtNum  TNcash  \
# 0                        1  171207106022464         101      23       1
# 1                        1  171207106022465         101      29       1
# 2                        1  171207106022466         101       3       1
# 3                        1  171207106022467         101      12       1
# 4                        1  171207106022468         101       7       1
# ...                    ...              ...         ...     ...     ...
# 126954                   1     190402106084         603       8       1
# 126955                   1     190402106085         603      17       1
# 126956                   1     190402106086         603      19       1
# 126957                   1     190402106087         603       9       0
# 126958                   1     190402106089         603       6       1
#
#         TNcard  Amount
# 0            0     112
# 1            0      54
# 2            0      14
# ...

# %%
x1 = op1.merge(tran1, on='OperatorID',how = 'inner')

# %%
x1
# Out:
#           WorkstationGroupID_x  WorkstationID         TranID_x  OperatorID  \
# 0                            8             16    1712071060162         266
# 1                            8             16    1712071060162         266
# 2                            8             16    1712071060162         266
# 3                            8             16    1712071060162         266
# 4                            8             16    1712071060162         266
# ...                        ...            ...              ...         ...
# 36925352                     1              4   19041010604968         304
# 36925353                     1              4   19041010604969         304
# 36925354                     1              4   19041010604969         304
# 36925355                     1              4  190410106041042         304
# 36925356                     1              4  190410106041042         304
#
# ...

# %%
x1.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','Data.csv'))

# %% [markdown]
# ## แบ่งตามช่วงเวลา

# %%
df2017=df_tran1.merge(df_op1[['OperatorID','BeginDateTime','Items']],how= 'left',on='OperatorID')

# %%
df201902=df_tran2.merge(df_op2[['OperatorID','BeginDateTime','Items']],how= 'left',on='OperatorID')

# %%
df201904=df_tran3.merge(df_op3[['OperatorID','BeginDateTime','Items']],how= 'left',on='OperatorID')

# %%
df2017.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','2017.csv'))
df201902.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','201902.csv'))
df201904.to_csv(os.path.join('/content/drive/MyDrive/DataViz_FinalData','201904.csv'))

# %% [markdown]
# ## สิ่งที่สนใจ

# %% [markdown]
# ### 1. ลูกค้าส่วนใหญ่นิยมจ่ายด้วย cash หรือ card มากกว่ากัน (TNcash,TNcard ข้อมูลซื้อ)

# %%
tran_concat[(tran_concat['TNcard']== False) & (tran_concat['TNcash']== False)]

# %%
tran_concat_drop = tran_concat[~((tran_concat['TNcard'] == False) & (tran_concat['TNcash'] == False))]
tran_concat_drop

# %%
tran_concat_drop['TNcash'] = tran_concat['TNcash'].replace('True', 'Cash')

# %%
tran_concat_drop

# %%
tran_concat_drop['TNcash']

# %% [markdown]
# ### 2. ลูกค้าส่วนใหญ่นิยมใช้บริการแบบ service หรือ self-service (WorkStationGroupID ข้อมูลซื้อ)

# %%
Service = tran_concat[tran_concat['WorkstationGroupID']==1]
Service
# Out:
#         WorkstationGroupID           TranID        BeginDateTime  \
# 0                        1  171207106022464  2017-12-07T14:23:23
# 1                        1  171207106022465  2017-12-07T14:25:09
# 2                        1  171207106022466  2017-12-07T14:27:28
# 3                        1  171207106022467  2017-12-07T14:28:04
# 4                        1  171207106022468  2017-12-07T14:29:40
# ...                    ...              ...                  ...
# 163264                   1  190410100000000  2019-04-10T14:05:20
# 163265                   1  190410100000000  2019-04-10T14:06:39
# 163266                   1  190410100000000  2019-04-10T14:07:51
# 163267                   1  190410100000000  2019-04-10T14:09:46
# 163268                   1  190410100000000  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
Service.describe()
# Out:
#        WorkstationGroupID                  TranID    OperatorID      TranTime  \
# count       123207.000000           123207.000000 123207.000000 123207.000000
# mean             1.000000   82062883645216.593750    171.380368     62.037441
# std              0.000000   87465824110894.359375    109.956414     48.369568
# min              1.000000     171207106044.000000     10.000000      0.000000
# 25%              1.000000   19021510605544.500000    112.000000     28.000000
# 50%              1.000000   19040410000000.000000    125.000000     50.000000
# 75%              1.000000  171214106021325.500000    143.000000     82.000000
# max              1.000000 1712121060201027.000000    606.000000    697.000000
#
#           BreakTime        ArtNum        Amount
# count 123207.000000 123207.000000 123207.000000
# mean      25.732239     17.657706     82.355843
# std       52.336845     17.649914     93.506244
# min      -12.000000      1.000000      0.000000
# ...

# %%
SelfService = tran_concat[tran_concat['WorkstationGroupID']==8]
SelfService
# Out:
#         WorkstationGroupID           TranID        BeginDateTime  \
# 45410                    8    1712071060144  2017-12-07T07:00:41
# 45411                    8    1712071060146  2017-12-07T07:08:01
# 45412                    8    1712071060148  2017-12-07T07:11:31
# 45413                    8   17120710601410  2017-12-07T07:15:53
# 45414                    8   17120710601412  2017-12-07T07:18:24
# ...                    ...              ...                  ...
# 155991                   8  190410100000000  2019-04-10T21:02:02
# 155992                   8  190410100000000  2019-04-10T21:04:51
# 155993                   8  190410100000000  2019-04-10T21:05:33
# 155994                   8  190410100000000  2019-04-10T21:06:34
# 155995                   8  190410100000000  2019-04-10T21:08:31
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 45410   2017-12-07T07:01:33         264        52        388       2   False
# ...

# %%
SelfService.describe()
# Out:
#        WorkstationGroupID                 TranID   OperatorID     TranTime  \
# count        40062.000000           40062.000000 40062.000000 40062.000000
# mean             8.000000 141961632593108.031250   267.251286    99.512331
# std              0.000000  70608977363693.906250     1.511208    82.027384
# min              8.000000   1712071060144.000000   264.000000     0.000000
# 25%              8.000000 171207106015402.500000   267.000000    42.000000
# 50%              8.000000 171216106017256.000000   268.000000    77.000000
# 75%              8.000000 190223106019309.750000   268.000000   131.000000
# max              8.000000 190410100000000.000000   269.000000  1137.000000
#
#          BreakTime       ArtNum       Amount
# count 40062.000000 40062.000000 40062.000000
# mean     92.572987     8.980580    42.724743
# std      98.313290     9.005207    53.062391
# min       5.000000     1.000000    -3.440000
# 25%      38.000000     3.000000    11.990000
# ...

# %% [markdown]
# ### 3. จำนวนครั้งของสถานะแคชเชียร์แต่ละประเภท (Items ข้อมูลlogin)

# %%
OperatorSignON = op_concat[op_concat['Items']=='OperatorSignOn']
OperatorSignONGroup = op_concat[op_concat['Items']=='OperatorSignOn'].groupby('Items').count().reset_index()
OperatorSignONGroup
# Out:
#             Items  WorkstationGroupID  WorkstationID  TranID  BeginDateTime  \
# 0  OperatorSignOn                3494           3494    3494           3494
#
#    OperatorID
# 0        3494

# %%
OperatorSignOff = op_concat[op_concat['Items']=='OperatorSignOff']
OperatorSignOffGroup = op_concat[op_concat['Items']=='OperatorSignOff'].groupby('Items').count().reset_index()
OperatorSignOffGroup
# Out:
#              Items  WorkstationGroupID  WorkstationID  TranID  BeginDateTime  \
# 0  OperatorSignOff                3485           3485    3485           3485
#
#    OperatorID
# 0        3485

# %%
OperatorUnlock = op_concat[op_concat['Items']=='OperatorUnLock']
OperatorUnLockGroup = op_concat[op_concat['Items']=='OperatorUnLock'].groupby('Items').count().reset_index()
OperatorUnLockGroup
# Out:
#             Items  WorkstationGroupID  WorkstationID  TranID  BeginDateTime  \
# 0  OperatorUnLock                3559           3559    3559           3559
#
#    OperatorID
# 0        3559

# %%
Operatorlock = op_concat[op_concat['Items']=='OperatorLock']
OperatorLockGroup = op_concat[op_concat['Items']=='OperatorLock'].groupby('Items').count().reset_index()
OperatorLockGroup
# Out:
#           Items  WorkstationGroupID  WorkstationID  TranID  BeginDateTime  \
# 0  OperatorLock                3566           3566    3566           3566
#
#    OperatorID
# 0        3566

# %% [markdown]
# ### 4. เปรียบเทียบการทำงานระหว่างเช้า (06:00:00-11:59:59)และ บ่าย (12:00:00-23:59:59) เป็นจำนวนครั้ง  (ข้อมูลlogin) (คำนวณจำนวนครั้ง,items >>รวมกับข้อ3เลยก้ได้)

# %% [markdown]
# ### 5. ระยะเวลาโดยเฉลี่ยที่ลูกค้าทำ transaction ต่อคน  (TranTimeข้อมูลการซื้อ)

# %%
tran_concat
# Out:
#         WorkstationGroupID           TranID        BeginDateTime  \
# 0                        1  171207106022464  2017-12-07T14:23:23
# 1                        1  171207106022465  2017-12-07T14:25:09
# 2                        1  171207106022466  2017-12-07T14:27:28
# 3                        1  171207106022467  2017-12-07T14:28:04
# 4                        1  171207106022468  2017-12-07T14:29:40
# ...                    ...              ...                  ...
# 163264                   1  190410100000000  2019-04-10T14:05:20
# 163265                   1  190410100000000  2019-04-10T14:06:39
# 163266                   1  190410100000000  2019-04-10T14:07:51
# 163267                   1  190410100000000  2019-04-10T14:09:46
# 163268                   1  190410100000000  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
avg_trantime = tran_concat['TranTime'].mean()
avg_trantime
# Out:
# 71.23281210762606

# %% [markdown]
# ### 6. รายได้รวมแต่ละวัน (Amount ข้อมูลการซื้อ)

# %%
df2017
# Out:
#          WorkstationGroupID           TranID      BeginDateTime_x  \
# 0                         1  171207106022464  2017-12-07T14:23:23
# 1                         1  171207106022464  2017-12-07T14:23:23
# 2                         1  171207106022464  2017-12-07T14:23:23
# 3                         1  171207106022464  2017-12-07T14:23:23
# 4                         1  171207106022464  2017-12-07T14:23:23
# ...                     ...              ...                  ...
# 7328677                   1    1712191060853  2017-12-19T11:52:37
# 7328678                   1    1712191060853  2017-12-19T11:52:37
# 7328679                   1    1712191060853  2017-12-19T11:52:37
# 7328680                   1    1712191060853  2017-12-19T11:52:37
# 7328681                   1    1712191060853  2017-12-19T11:52:37
#
#                  EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0        2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
Amount_sum2017 = df2017[['Amount']].sum()
Amount_sum2017
# Out:
# Amount   611817482.780001
# dtype: float64

# %%
df201902
# Out:
#          WorkstationGroupID          TranID      BeginDateTime_x  \
# 0                         1  19022310606223  2019-02-23T14:35:12
# 1                         1  19022310606223  2019-02-23T14:35:12
# 2                         1  19022310606223  2019-02-23T14:35:12
# 3                         1  19022310606223  2019-02-23T14:35:12
# 4                         1  19022310606223  2019-02-23T14:35:12
# ...                     ...             ...                  ...
# 8638567                   1  19022310606500  2019-02-23T19:43:19
# 8638568                   1  19022310606500  2019-02-23T19:43:19
# 8638569                   1  19022310606500  2019-02-23T19:43:19
# 8638570                   1  19022310606500  2019-02-23T19:43:19
# 8638571                   1  19022310606500  2019-02-23T19:43:19
#
#                  EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0        2019-02-23T14:35:12          10         0          2       1   False
# ...

# %%
Amount_sum201902 = df201902[['Amount']].sum()
Amount_sum201902
# Out:
# Amount   636539914.799999
# dtype: float64

# %%
df201904
# Out:
#          WorkstationGroupID                 TranID      BeginDateTime_x  \
# 0                         1  19040310601356.000000  2019-04-03T13:28:17
# 1                         1  19040310601356.000000  2019-04-03T13:28:17
# 2                         1  19040310601356.000000  2019-04-03T13:28:17
# 3                         1  19040310601356.000000  2019-04-03T13:28:17
# 4                         1  19040310601356.000000  2019-04-03T13:28:17
# ...                     ...                    ...                  ...
# 5905669                   1 190410100000000.000000  2019-04-10T14:10:29
# 5905670                   1 190410100000000.000000  2019-04-10T14:10:29
# 5905671                   1 190410100000000.000000  2019-04-10T14:10:29
# 5905672                   1 190410100000000.000000  2019-04-10T14:10:29
# 5905673                   1 190410100000000.000000  2019-04-10T14:10:29
#
#                  EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# ...

# %%
Amount_sum201904 = df201904[['Amount']].sum()
Amount_sum201904
# Out:
# Amount   457772197.600000
# dtype: float64
